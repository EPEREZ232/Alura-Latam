# %% [markdown]
# <a href="https://colab.research.google.com/github/EPEREZ232/Alura-Latam/blob/main/Biblioteca_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install matplotlib

# %%
matplotlib.__versión__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-dcb00e403832> in <cell line: 0>()
# ----> 1 matplotlib.__versión__
#
# NameError: name 'matplotlib' is not defined

# %%
import matplotlib

# %%
version_matplotlib = matplotlib.__version__

# %%
matplotlib.__version__
# Out:
# '3.10.0'

# %%
# !pip list
# Out:
# Package                               Version
# ------------------------------------- -------------------
# absl-py                               1.4.0
# accelerate                            1.5.2
# aiohappyeyeballs                      2.6.1
# aiohttp                               3.11.15
# aiosignal                             1.3.2
# alabaster                             1.0.0
# albucore                              0.0.23
# albumentations                        2.0.5
# ale-py                                0.10.2
# altair                                5.5.0
# annotated-types                       0.7.0
# anyio                                 4.9.0
# argon2-cffi                           23.1.0
# argon2-cffi-bindings                  21.2.0
# array_record                          0.7.1
# arviz                                 0.21.0
# astropy                               7.0.1
# astropy-iers-data                     0.2025.4.14.0.37.22
# ...

# %%
from matplotlib import pyplot as plt

# %%
estudiantes = ['Juan', 'Daniel', 'Ruben']
notas = [ 9 , 8.5, 6.5]

# %%
plt.bar ( x= estudiantes, height=notas)
plt.show()

# %%
from random import choice

# %%
estudiante = choice(estudiantes_2)
estudiante
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-6392567b3ecc> in <cell line: 0>()
# ----> 1 estudiante = choice(estudiantes_2)
#       2 estudiante
#
# NameError: name 'estudiantes_2' is not defined

# %%
 import pandas as pd
